# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit
from datetime import datetime
import time
import wikipedia
import pyjokes
import os
import requests
import ctypes
import random
import webbrowser
import subprocess
import re
listener = sr.Recognizer()
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)


def talk(text):
    engine.say(text)
    engine.runAndWait()


def take_command():
    try:
        with sr.Microphone() as source:
            print('listening...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'nino' in command:
                command = command.replace('nino', '')
                print(command)
    except:
        pass
    return command

def run_alexa():
    command = take_command()
    print(command)
    if 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        talk('Current time is ' + time)
    elif 'who is' in command:
        person = command.replace('who is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)
    elif 'hi' in command:
        talk('hello')
    elif 'how are you' in command:
        talk('I am fine, what about you')
    elif 'good' in command:
        talk('glad to hear that')
    elif 'what is your name' in command:
        talk('my name is aman')
    elif 'joke' in command:
        talk(pyjokes.get_joke())
   
    elif 'weather' in command:
        city = "chandigarh"
        Api_Key = "2ddb3362f9083944b03834fc6646d8e3"
        final_URL = "http://api.openweathermap.org/data/2.5/weather?q={}&appid={}".format(city, Api_Key)
        result = requests.get(final_URL)
        data = result.json()
        if data['cod'] == '404':
            print("Invalid City: {}, Please check your city name".format(city))
        temperature = ((data['main']['temp']) - 273.15)
        weath_desc = data['weather'][0]['description']
        hmdt = data['main']['humidity']
        wnd_spd = data['wind']['speed']
        date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")
        talk('Date and time')
        talk(date_time)
        talk("Weather statistics for")
        talk(city)
        talk("Current temperature is ")
        talk(temperature)
        talk("Current weather description")
        talk(weath_desc)
        talk("Current Humidity")
        talk(hmdt)
        talk("percent")
        talk("Current wind speed ")
        talk(wnd_spd)
        talk("kmph")
    

    elif 'news' in command:
        api_key = "55c89d8c534d4773b8bc3d0422b0186e"
        main_url = "https://newsapi.org/v2/top-headlines?country=in&apiKey=" + api_key
        news = requests.get(main_url).json()
        article = news["articles"]
        talk(article)
        news_article = []
        for arti in article:
            news_article.append(arti['title'])
            talk(news_article)
        for i in range(1):
            talk(news_article[i])

    elif 'alarm' in command:
        talk("sir please tell me the time to set alarm. for example, set alarm to 5:30 am")
        tt = take_command()  # set alarm to 5:30 a.m.
        tt = tt.replace("set alarm to ", "")  # 5:30 a.m.
        tt = tt.replace(".", "")  # 5:30 am
        tt = tt.upper()  # 5:30 AM
        import Alarm
        Alarm.alarm(tt)

    elif 'wikipedia' in command:  #if wikipedia found in the query then this block will be executed
            talk('Searching Wikipedia...')
            command = command.replace("wikipedia", "")
            results = wikipedia.summary(command, sentences=2) 
            talk("According to Wikipedia")
            print(results)
            talk(results)
    elif 'open google' in command:
        #matching command to check it is available
        reg_ex = re.search('open google (.*)', command)
        url = 'https://www.google.com/'
        if reg_ex:
            subgoogle = reg_ex.group(1)
            url = url + 'r/' + subreddit
        webbrowser.open(url)
        talk(Done)
    elif 'open youtube' in command:
        talk('opening youtube')
        webbrowser.open('https://youtube.com/', new=2)
    elif 'open python editor' in command:
        webbrowser.open("https://www.onlinegdb.com/online_python_compiler")
    elif 'change background image' in command or "change wallpaper" in command:
        img = r'C:\Users\hp\Desktop\wallpa'
        list_img = os.listdir(img)
        img_choice = random.choice(list_img)
        random_img = os.path.join(img, img_choice)
        ctypes.windll.user32.SystemParametersInfoW(20,random_img,0)
        talk("Background image changed successfully")
    elif 'open chrome' in command:
        talk('opening google chrome')
        os.startfile(
            r"C:\Program Files\Google\Chrome\Application\chrome.exe"
        )
    else:
        talk('Please say the command again.')


while True:
    run_alexa()
# Out:
# listening...
# open google
# Done!
# listening...
# play outside by zayn malik
# listening...
